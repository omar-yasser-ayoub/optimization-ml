# %%
import matplotlib as mpl
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import fastf1 as ff1

# %%
# 2️⃣ set parameter
year = 2025
wknd = 21
ses = 'R'
driver = 'VER'
colormap = mpl.cm.plasma

# 3️⃣ Laod session
session = ff1.get_session(year, wknd, ses)
session.load()
weekend = session.event

# 4️⃣ Pick the Fastest Lap of the driver
lap = session.laps.pick_drivers(driver).pick_fastest()

# 4.1️ Extract telemetry with coordinates
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (102.16 MB) C:\Users\pc\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for São Paulo Grand Prix - Race [v3.7.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core        WARNING 	Driver 4 completed the race distance 00:00.010000 before the recorded end of the session.
# core           INFO 	Finished loading data for 20 drivers: ['4', '12', '1', '63', '81', '87', '30', '6', '27', '10', '23', '31', '55', '14', '43', '18', '22', '44', '16', '5']

# %%
telemetry = lap.get_telemetry().add_distance()

# %%
telemetry
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2025-11-09 18:15:54.925 0 days 02:09:35.326000
# 3   2025-11-09 18:15:55.060 0 days 02:09:35.461000
# 4   2025-11-09 18:15:55.123 0 days 02:09:35.524000
# 5   2025-11-09 18:15:55.260 0 days 02:09:35.661000          63
# 6   2025-11-09 18:15:55.563 0 days 02:09:35.964000          63
# ..                      ...                    ...         ...
# 556 2025-11-09 18:17:06.980 0 days 02:10:47.381000          63
# 557 2025-11-09 18:17:06.983 0 days 02:10:47.384000          63
# 558 2025-11-09 18:17:07.183 0 days 02:10:47.584000          63
# 559 2025-11-09 18:17:07.260 0 days 02:10:47.661000          63
# 560 2025-11-09 18:17:07.372 0 days 02:10:47.773000          63
#
#      DistanceToDriverAhead                   Time           RPM    Speed  \
# 2               355.825833        0 days 00:00:00  11085.687501  312.000
# 3               355.825833 0 days 00:00:00.135000  11084.000000  312.000
# 4               355.825833 0 days 00:00:00.198000  11094.710011  312.315
# 5               355.825833 0 days 00:00:00.335000  11118.000000  313.000
# 6               338.319163 0 days 00:00:00.638000  11121.787501  313.000
# ..                     ...                    ...           ...      ...
# 556             366.427778 0 days 00:01:12.055000  11101.000000  313.000
# 557             366.281108 0 days 00:01:12.058000  11101.042858  313.000
# 558             356.503330 0 days 00:01:12.258000  11103.900001  313.000
# 559             352.738889 0 days 00:01:12.335000  11105.000000  313.000
# 560             352.738889 0 days 00:01:12.447000  11112.700000  313.000
#
#      nGear  Throttle  Brake  DRS         Source  RelativeDistance   Status  \
# 2        8     100.0  False    0  interpolation         -0.000002  OnTrack
# 3        8     100.0  False    0            car          0.002755  OnTrack
# 4        8     100.0  False    0            pos          0.004044  OnTrack
# 5        8     100.0  False    0            car          0.006849  OnTrack
# 6        8     100.0  False    0            pos          0.013052  OnTrack
# ..     ...       ...    ...  ...            ...               ...      ...
# 556      8     100.0  False    0            car          0.987717  OnTrack
# 557      8     100.0  False    0            pos          0.987778  OnTrack
# 558      8     100.0  False    0            pos          0.991873  OnTrack
# 559      8     100.0  False    0            car          0.993449  OnTrack
# 560      8     100.0  False    0  interpolation          0.995742  OnTrack
#
#                X            Y            Z     Distance
# 2   -3673.757485 -5271.157697  7767.933272     0.000000
# 3   -3640.462974 -5402.176738  7771.990166    11.700000
# 4   -3625.000000 -5463.000000  7774.000000    17.165513
# 5   -3591.540573 -5594.554331  7778.625977    29.076901
# 6   -3526.000000 -5851.000000  7788.000000    55.421068
# ..           ...          ...          ...          ...
# 556 -3776.854071 -4862.582500  7755.899973  4195.472511
# 557 -3776.000000 -4866.000000  7756.000000  4195.733344
# 558 -3702.000000 -5160.000000  7765.000000  4213.122233
# 559 -3676.413582 -5261.442398  7768.078091  4219.816955
# 560 -3645.787565 -5382.800344  7771.667590  4229.554733
#
# [559 rows x 18 columns]
